# %%
# read Geojson file
import numpy as np
import pandas as pd
import geopandas as gpd
import datetime as dt
import time
import matplotlib.pyplot as plt
# WORK_PATH = "/Users/fangzeqiang/Desktop/SDSV-T2/CASA0006-DSSS/Assessment/"

import ssl
ssl._create_default_https_context = ssl._create_unverified_context
# supported by StackOverflow https://stackoverflow.com/questions/27835619/urllib-and-ssl-certificate-verify-failed-error

# This process may take 3 seconds,
t1 = time.time()
url_geo = "Local_Authority_Districts_(December_2011)_Boundaries_EW_BFC.geojson"
print('Loading data from ', url_geo)
gdf = gpd.read_file(url_geo)
print('time taken', time.time()-t1, 'second')

gdf.plot()
plt.savefig('figpath.png', dpi=800, bbox_inches='tight')
# Out:
# Loading data from  Local_Authority_Districts_(December_2011)_Boundaries_EW_BFC.geojson
# time taken 7.783308506011963 second

# %%
gdf
# Out:
#        lad11cd lad11cdo               lad11nm        lad11nmw  objectid  \
# 0    E06000001     00EB            Hartlepool                         1
# 1    E06000002     00EC         Middlesbrough                         2
# 2    E06000003     00EE  Redcar and Cleveland                         3
# 3    E06000004     00EF      Stockton-on-Tees                         4
# 4    E06000005     00EH            Darlington                         5
# ..         ...      ...                   ...             ...       ...
# 343  W06000020     00PM               Torfaen        Tor-faen       344
# 344  W06000021     00PP         Monmouthshire       Sir Fynwy       345
# 345  W06000022     00PR               Newport       Casnewydd       346
# 346  W06000023     00NN                 Powys           Powys       347
# 347  W06000024     00PH        Merthyr Tydfil  Merthyr Tudful       348
#
#      st_lengthshape  st_areashape  \
# 0      71094.507394  9.386527e+07
# 1      46457.241989  5.388298e+07
# 2      94877.626976  2.448871e+08
# 3     160177.916301  2.039312e+08
# 4     107084.784670  1.974749e+08
# ..              ...           ...
# 343    81524.468028  1.261757e+08
# 344   222982.985050  8.503376e+08
# 345   152430.883102  1.905177e+08
# 346   604788.311647  5.195238e+09
# 347    66235.444329  1.119198e+08
#
#                                               geometry
# 0    MULTIPOLYGON (((-1.26846 54.72612, -1.26858 54...
# 1    MULTIPOLYGON (((-1.24922 54.59070, -1.24946 54...
# 2    MULTIPOLYGON (((-1.13758 54.64581, -1.13743 54...
# 3    MULTIPOLYGON (((-1.31769 54.64498, -1.31771 54...
# 4    POLYGON ((-1.63768 54.61714, -1.63800 54.61720...
# ..                                                 ...
# 343  POLYGON ((-3.10490 51.79504, -3.10498 51.79508...
# 344  MULTIPOLYGON (((-3.05202 51.97282, -3.05215 51...
# 345  MULTIPOLYGON (((-2.83456 51.64684, -2.83449 51...
# 346  POLYGON ((-3.15512 52.89796, -3.15500 52.89803...
# 347  POLYGON ((-3.40441 51.82241, -3.40440 51.82252...
#
# [348 rows x 8 columns]

# %%
# read the data
# This reading operation might take 25s because the size of it is 25MB 
t0 = time.time()
url = "aaa.xlsx"
print('Loading data from ', url)
df = pd.read_excel(url)
print('time taken', time.time()-t0, 'second')
# df.info()
df
# Out:
# Loading data from  aaa.xlsx
# time taken 0.09160733222961426 second
#      Area code                Area name  \
# 0    E06000001            Hartlepool UA
# 1    E06000002         Middlesbrough UA
# 2    E06000003  Redcar and Cleveland UA
# 3    E06000004      Stockton-on-Tees UA
# 4    E06000005            Darlington UA
# ..         ...                      ...
# 343  W06000020                  Torfaen
# 344  W06000021            Monmouthshire
# 345  W06000022                  Newport
# 346  W06000023                    Powys
# 347  W06000024           Merthyr Tydfil
#
#      All categories: Method of travel to work (alternative)  \
# 0                                                66804
# 1                                               100551
# 2                                                99177
# 3                                               140654
# 4                                                76635
# ..                                                 ...
# 343                                              66107
# 344                                              66107
# 345                                             105141
# 346                                              96069
# 347                                              43377
#
#      Work mainly at or from home  Underground, metro, light rail, tram  Train  \
# 0                            3.7                                   0.0    0.7
# 1                            3.3                                   0.0    0.7
# 2                            4.1                                   0.0    1.2
# 3                            4.5                                   0.1    0.8
# 4                            5.5                                   0.0    1.1
# ..                           ...                                   ...    ...
# 343                          3.9                                   0.0    0.7
# 344                         10.0                                   0.1    1.3
# 345                          4.5                                   0.1    1.2
# 346                         14.2                                   0.1    0.4
# 347                          3.9                                   0.1    1.1
#
#      Bus, minibus or coach  Taxi  Motorcycle, scooter or moped  \
# 0                      3.8   1.0                           0.3
# 1                      4.8   0.9                           0.2
# 2                      3.3   0.4                           0.3
# 3                      3.6   0.4                           0.3
# 4                      4.4   0.5                           0.2
# ..                     ...   ...                           ...
# 343                    2.9   0.5                           0.5
# 344                    0.9   0.1                           0.5
# 345                    4.8   0.4                           0.4
# 346                    0.7   0.1                           0.2
# 347                    4.0   0.5                           0.2
#
#      Driving a car or van  Passenger in a car or van  Bicycle  On foot  \
# 0                    34.2                        4.7      1.1      6.4
# 1                    31.0                        4.6      1.4      6.7
# 2                    36.6                        4.0      0.9      5.4
# 3                    41.1                        4.3      1.2      5.0
# 4                    37.8                        4.4      1.5      8.2
# ..                    ...                        ...      ...      ...
# 343                  42.4                        4.7      0.5      4.7
# 344                  41.8                        3.4      0.7      5.7
# 345                  38.9                        4.4      0.9      5.4
# 346                  39.0                        3.0      0.9      7.4
# 347                  36.4                        6.0      0.2      5.4
#
#      Other method of travel to work  Not in employment
# 0                               0.5               43.5
# 1                               0.6               45.8
# 2                               0.7               43.2
# 3                               0.6               38.1
# 4                               0.3               36.0
# ..                              ...                ...
# 343                             0.2               39.1
# 344                             0.3               35.2
# 345                             0.3               38.7
# 346                             0.3               33.7
# 347                             0.2               42.1
#
# [348 rows x 15 columns]

# %%
dfmg = pd.merge(df,gdf,left_on='Area code',right_on='lad11cd',how='inner')
dfmg.head()
# Out:
#    Area code                Area name  \
# 0  E06000001            Hartlepool UA
# 1  E06000002         Middlesbrough UA
# 2  E06000003  Redcar and Cleveland UA
# 3  E06000004      Stockton-on-Tees UA
# 4  E06000005            Darlington UA
#
#    All categories: Method of travel to work (alternative)  \
# 0                                              66804
# 1                                             100551
# 2                                              99177
# 3                                             140654
# 4                                              76635
#
#    Work mainly at or from home  Underground, metro, light rail, tram  Train  \
# 0                          3.7                                   0.0    0.7
# 1                          3.3                                   0.0    0.7
# 2                          4.1                                   0.0    1.2
# 3                          4.5                                   0.1    0.8
# 4                          5.5                                   0.0    1.1
#
#    Bus, minibus or coach  Taxi  Motorcycle, scooter or moped  \
# 0                    3.8   1.0                           0.3
# 1                    4.8   0.9                           0.2
# 2                    3.3   0.4                           0.3
# 3                    3.6   0.4                           0.3
# 4                    4.4   0.5                           0.2
#
#    Driving a car or van  ...  Other method of travel to work  \
# 0                  34.2  ...                             0.5
# 1                  31.0  ...                             0.6
# 2                  36.6  ...                             0.7
# 3                  41.1  ...                             0.6
# 4                  37.8  ...                             0.3
#
#    Not in employment    lad11cd  lad11cdo               lad11nm lad11nmw  \
# 0               43.5  E06000001      00EB            Hartlepool
# 1               45.8  E06000002      00EC         Middlesbrough
# 2               43.2  E06000003      00EE  Redcar and Cleveland
# 3               38.1  E06000004      00EF      Stockton-on-Tees
# 4               36.0  E06000005      00EH            Darlington
#
#   objectid st_lengthshape  st_areashape  \
# 0        1   71094.507394  9.386527e+07
# 1        2   46457.241989  5.388298e+07
# 2        3   94877.626976  2.448871e+08
# 3        4  160177.916301  2.039312e+08
# 4        5  107084.784670  1.974749e+08
#
#                                             geometry
# 0  MULTIPOLYGON (((-1.26846 54.72612, -1.26858 54...
# 1  MULTIPOLYGON (((-1.24922 54.59070, -1.24946 54...
# 2  MULTIPOLYGON (((-1.13758 54.64581, -1.13743 54...
# 3  MULTIPOLYGON (((-1.31769 54.64498, -1.31771 54...
# 4  POLYGON ((-1.63768 54.61714, -1.63800 54.61720...
#
# [5 rows x 23 columns]

# %%
dfmg["Public Transport"] = dfmg["Underground, metro, light rail, tram"] + dfmg["Train"] + dfmg["Bus, minibus or coach"] 
dfmg["Taxi/Motorcycle/Car/Van"] = dfmg["Taxi"] + dfmg["Motorcycle, scooter or moped"] + dfmg["Driving a car or van"] + dfmg["Passenger in a car or van"]

# %%
from sklearn.preprocessing import RobustScaler, MinMaxScaler
rs = RobustScaler(quantile_range=(10.0, 90.0))

to_cluster = dfmg[['Area code', "Public Transport","Taxi/Motorcycle/Car/Van",'Bicycle', "On foot"]].set_index('Area code').copy()
# to_cluster = dfmg[['Area code', "Work mainly at or from home", "Underground, metro, light rail, tram", 'Train', 'Bus, minibus or coach', "Taxi",
#                   "Motorcycle, scooter or moped", "Driving a car or van", "Passenger in a car or van", "Bicycle", "On foot"]].set_index('Area code').copy()
to_cluster.head()

# normnise the value
normed = to_cluster.copy()
for c in to_cluster.columns.values:
    normed[c] = rs.fit_transform(to_cluster[c].values.reshape(-1,1))
normed
# Out:
#            Public Transport  Taxi/Motorcycle/Car/Van   Bicycle  On foot
# Area code
# E06000001         -0.070093                -0.170427 -0.125000     0.10
# E06000002         -0.003338                -0.338454  0.000000     0.16
# E06000003         -0.070093                -0.117619 -0.208333    -0.10
# E06000004         -0.070093                 0.112818 -0.083333    -0.18
# E06000005         -0.003338                -0.040807  0.041667     0.46
# ...                     ...                      ...       ...      ...
# W06000020         -0.130174                 0.208833 -0.375000    -0.24
# W06000021         -0.216956                 0.098416 -0.291667    -0.04
# W06000022          0.036716                 0.016803 -0.208333    -0.10
# W06000023         -0.290387                -0.069611 -0.208333     0.30
# W06000024         -0.023364                -0.031205 -0.500000    -0.10
#
# [348 rows x 4 columns]

# %%
import pysal as ps
import numpy as np
import pandas as pd
import seaborn as sns
import geopandas as gpd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
# calculate SSE for a range of number of cluster
list_SSE = []
min_k = 1
max_k = 10
range_k = range(min_k, max_k+1)
for i in range_k:
    km = KMeans(
        n_clusters=i, init='random',
        n_init=10, max_iter=300,
        tol=1e-04, random_state=0
    )
    km.fit(to_cluster)
    # inertia is a concept in physics. Roughly it means SSE of clustering.
    list_SSE.append(km.inertia_)

# plot
plt.plot(range_k, list_SSE, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('SSE')
plt.savefig('figpath.png', dpi=400, bbox_inches='tight')
plt.show()
# plt.savefig('figpath.png', dpi=800, bbox_inches='tight')

# %%
# re-run the k-means process
from sklearn.cluster import KMeans
from sklearn import metrics
k_cluster = 3
random_seed = 1
kmeans_method = KMeans(n_clusters=k_cluster,random_state=random_seed)
kmeans_method.fit(normed)

gdf['Kmeans_Cluster'] = kmeans_method.labels_
fig_kmeans_4 = gdf.plot(column='Kmeans_Cluster', categorical=True, legend=True, figsize=(12,8),cmap = 'plasma')
from sklearn import metrics
print("Silhouette Score is :")
print(metrics.silhouette_score(normed, gdf['Kmeans_Cluster']))
plt.savefig('figpath.png', dpi=400, bbox_inches='tight')
# Out:
# Silhouette Score is :
# 0.6225178605468793

# %%
kmeans_label = pd.DataFrame(kmeans_method.labels_, columns = ['kmeans_label'])
kmeans_label
# to_cluster_labeled = pd.concat([to_cluster, DB_label], axis = 1).dropna()

# temp = to_cluster.join(kmeans_label)
to_cluster_labeled = to_cluster.copy()
to_cluster_labeled["kmeans_label"] = kmeans_method.labels_
to_cluster_labeled

summary_df_kmeans = to_cluster_labeled[["Public Transport","Taxi/Motorcycle/Car/Van",'Bicycle', "On foot",'kmeans_label']].groupby('kmeans_label').mean().round()

summary_df_kmeans['count'] = to_cluster_labeled.kmeans_label.value_counts()
summary_df_kmeans
# Out:
#               Public Transport  Taxi/Motorcycle/Car/Van  Bicycle  On foot  \
# kmeans_label
# 0                         32.0                     19.0      2.0      5.0
# 1                          6.0                     44.0      2.0      6.0
# 2                         10.0                     27.0      7.0     13.0
#
#               count
# kmeans_label
# 0                30
# 1               305
# 2                13
