# %%
# read Geojson file
import numpy as np
import pandas as pd
import geopandas as gpd
import datetime as dt
import time
import matplotlib.pyplot as plt
# WORK_PATH = "/Users/fangzeqiang/Desktop/SDSV-T2/CASA0006-DSSS/Assessment/"

import ssl
ssl._create_default_https_context = ssl._create_unverified_context
# supported by StackOverflow https://stackoverflow.com/questions/27835619/urllib-and-ssl-certificate-verify-failed-error

# This process may take 3 seconds,
t1 = time.time()
url_geo = "london_boroughs.json"
print('Loading data from ', url_geo)
gdf = gpd.read_file(url_geo)
print('time taken', time.time()-t1, 'second')

gdf.plot()
plt.savefig('figpath.png', dpi=800, bbox_inches='tight')
# Out:
# Loading data from  london_boroughs.json
# time taken 0.4764575958251953 second

# %%
gdf
# Out:
#     id                    name       code  area_hectares  inner_statistical  \
# 0    1    Kingston upon Thames  E09000021       3726.117              False
# 1    2                 Croydon  E09000008       8649.441              False
# 2    3                 Bromley  E09000006      15013.487              False
# 3    4                Hounslow  E09000018       5658.541              False
# 4    5                  Ealing  E09000009       5554.428              False
# 5    6                Havering  E09000016      11445.735              False
# 6    7              Hillingdon  E09000017      11570.063              False
# 7    8                  Harrow  E09000015       5046.330              False
# 8    9                   Brent  E09000005       4323.270              False
# 9   10                  Barnet  E09000003       8674.837              False
# 10  11                 Lambeth  E09000022       2724.940               True
# 11  12               Southwark  E09000028       2991.340               True
# 12  13                Lewisham  E09000023       3531.706               True
# 13  14               Greenwich  E09000011       5044.190              False
# 14  15                  Bexley  E09000004       6428.649              False
# 15  16                 Enfield  E09000010       8220.025              False
# 16  17          Waltham Forest  E09000031       3880.793              False
# 17  18               Redbridge  E09000026       5644.225              False
# 18  19                  Sutton  E09000029       4384.698              False
# 19  20    Richmond upon Thames  E09000027       5876.111              False
# 20  21                  Merton  E09000024       3762.466              False
# 21  22              Wandsworth  E09000032       3522.022               True
# 22  23  Hammersmith and Fulham  E09000013       1715.409               True
# 23  24  Kensington and Chelsea  E09000020       1238.379               True
# 24  25             Westminster  E09000033       2203.005               True
# 25  26                  Camden  E09000007       2178.932               True
# 26  27           Tower Hamlets  E09000030       2157.501               True
# 27  28               Islington  E09000019       1485.664               True
# 28  29                 Hackney  E09000012       1904.902               True
# 29  30                Haringey  E09000014       2959.837               True
# 30  31                  Newham  E09000025       3857.806               True
# 31  32    Barking and Dagenham  E09000002       3779.934              False
# 32  33          City of London  E09000001        314.942               True
#
#                                              geometry
# 0   MULTIPOLYGON (((-0.33068 51.32901, -0.33059 51...
# 1   MULTIPOLYGON (((-0.06402 51.31864, -0.06408 51...
# 2   MULTIPOLYGON (((0.01213 51.29960, 0.01196 51.2...
# 3   MULTIPOLYGON (((-0.24456 51.48870, -0.24468 51...
# 4   MULTIPOLYGON (((-0.41183 51.53408, -0.41188 51...
# 5   MULTIPOLYGON (((0.15869 51.51219, 0.15871 51.5...
# 6   MULTIPOLYGON (((-0.40407 51.61318, -0.40388 51...
# 7   MULTIPOLYGON (((-0.40407 51.61318, -0.40320 51...
# 8   MULTIPOLYGON (((-0.19657 51.52765, -0.19685 51...
# 9   MULTIPOLYGON (((-0.19990 51.67017, -0.19970 51...
# 10  MULTIPOLYGON (((-0.12846 51.48505, -0.12843 51...
# 11  MULTIPOLYGON (((-0.10892 51.50844, -0.10889 51...
# 12  MULTIPOLYGON (((-0.03241 51.49306, -0.03240 51...
# 13  MULTIPOLYGON (((0.12021 51.51144, 0.12054 51.5...
# 14  MULTIPOLYGON (((0.12021 51.51144, 0.12159 51.5...
# 15  MULTIPOLYGON (((-0.10580 51.69187, -0.10557 51...
# 16  MULTIPOLYGON (((0.01924 51.60822, 0.01931 51.6...
# 17  MULTIPOLYGON (((0.06937 51.54413, 0.06910 51.5...
# 18  MULTIPOLYGON (((-0.15657 51.32151, -0.15866 51...
# 19  MULTIPOLYGON (((-0.32173 51.46541, -0.32172 51...
# 20  MULTIPOLYGON (((-0.13432 51.39093, -0.13438 51...
# 21  MULTIPOLYGON (((-0.22343 51.47152, -0.22327 51...
# 22  MULTIPOLYGON (((-0.24456 51.48870, -0.24460 51...
# 23  MULTIPOLYGON (((-0.18388 51.47742, -0.18403 51...
# 24  MULTIPOLYGON (((-0.15000 51.48548, -0.15009 51...
# 25  MULTIPOLYGON (((-0.14242 51.56912, -0.14250 51...
# 26  MULTIPOLYGON (((-0.07938 51.50784, -0.07935 51...
# 27  MULTIPOLYGON (((-0.13839 51.55686, -0.13852 51...
# 28  MULTIPOLYGON (((-0.09766 51.57365, -0.09756 51...
# 29  MULTIPOLYGON (((-0.09766 51.57365, -0.09780 51...
# 30  MULTIPOLYGON (((-0.00786 51.52301, -0.00811 51...
# 31  MULTIPOLYGON (((0.06971 51.54406, 0.07035 51.5...
# 32  MULTIPOLYGON (((-0.11157 51.51075, -0.11159 51...

# %%
# read the data
# This reading operation might take 25s because the size of it is 25MB 
t0 = time.time()
url = "london_method.xlsx"
print('Loading data from ', url)
df = pd.read_excel(url)
print('time taken', time.time()-t0, 'second')
# df.info()
df
# Out:
# Loading data from  london_method.xlsx
# time taken 0.07434630393981934 second
#          code                 borough    Car  Public Transport  \
# 0   E09000001          City of London    165              1048
# 1   E09000002    Barking and Dagenham  25542             21594
# 2   E09000003                  Barnet  54969             55335
# 3   E09000004                  Bexley  46845             11266
# 4   E09000005                   Brent  35428             56847
# 5   E09000006                 Bromley  53815             14627
# 6   E09000007                  Camden  10593             47219
# 7   E09000008                 Croydon  56487             31976
# 8   E09000009                  Ealing  48569             57541
# 9   E09000010                 Enfield  52093             33756
# 10  E09000011               Greenwich  29256             31430
# 11  E09000012                 Hackney  12271             47049
# 12  E09000013  Hammersmith and Fulham  12022             46996
# 13  E09000014                Haringey  20172             55270
# 14  E09000015                  Harrow  42686             33411
# 15  E09000016                Havering  48223             17656
# 16  E09000017              Hillingdon  62561             29529
# 17  E09000018                Hounslow  46153             35116
# 18  E09000019               Islington   9512             48416
# 19  E09000020  Kensington and Chelsea  11730             35738
# 20  E09000021    Kingston upon Thames  28120             10266
# 21  E09000022                 Lambeth  18713             73189
# 22  E09000023                Lewisham  26304             37123
# 23  E09000024                  Merton  25441             31543
# 24  E09000025                  Newham  23216             55679
# 25  E09000026               Redbridge  41673             39764
# 26  E09000027    Richmond upon Thames  29383             15974
# 27  E09000028               Southwark  17001             60040
# 28  E09000029                  Sutton  40934             12966
# 29  E09000030           Tower Hamlets  12765             54823
# 30  E09000031          Waltham Forest  29780             42983
# 31  E09000032              Wandsworth  24929             65880
# 32  E09000033             Westminster  11290             47863
#
#     Bicycle/On Foot   Total
# 0              2340    3790
# 1              5218   60234
# 2             11167  130359
# 3              6684   89775
# 4             12668  113458
# 5             10438  121537
# 6             21855   85935
# 7             13792  140506
# 8             14756  129519
# 9              9663  110338
# 10             9146   94561
# 11            27311   94086
# 12            18084   80957
# 13            12081   95332
# 14             7298   90023
# 15             7341   91798
# 16             9805  106950
# 17            12147  102654
# 18            24475   87839
# 19            12035   61763
# 20            10553   66083
# 21            23246  136137
# 22            12582  110288
# 23             9707   84234
# 24             9909  102055
# 25             7628   99641
# 26            12462   77635
# 27            26196  120691
# 28             8857   79019
# 29            27048  101296
# 30            10054   93493
# 31            24030  147954
# 32            23821   87666

# %%
df.describe()
# Out:
#                 Car  Public Transport  Bicycle/On Foot          Total
# count     33.000000         33.000000        33.000000      33.000000
# mean   30564.878788      38179.181818     13769.606061   96897.151515
# std    16701.611368      17984.230760      6957.527178   27368.051510
# min      165.000000       1048.000000      2340.000000    3790.000000
# 25%    17001.000000      29529.000000      9663.000000   85935.000000
# 50%    28120.000000      37123.000000     12035.000000   94561.000000
# 75%    46153.000000      54823.000000     18084.000000  110338.000000
# max    62561.000000      73189.000000     27311.000000  147954.000000

# %%
dfmg = pd.merge(df,gdf,left_on='code',right_on='code',how='inner')
dfmg.head()
# Out:
#         code               borough    Car  Public Transport  Bicycle/On Foot  \
# 0  E09000001        City of London    165              1048             2340
# 1  E09000002  Barking and Dagenham  25542             21594             5218
# 2  E09000003                Barnet  54969             55335            11167
# 3  E09000004                Bexley  46845             11266             6684
# 4  E09000005                 Brent  35428             56847            12668
#
#     Total  id                  name  area_hectares  inner_statistical  \
# 0    3790  33        City of London        314.942               True
# 1   60234  32  Barking and Dagenham       3779.934              False
# 2  130359  10                Barnet       8674.837              False
# 3   89775  15                Bexley       6428.649              False
# 4  113458   9                 Brent       4323.270              False
#
#                                             geometry
# 0  MULTIPOLYGON (((-0.11157 51.51075, -0.11159 51...
# 1  MULTIPOLYGON (((0.06971 51.54406, 0.07035 51.5...
# 2  MULTIPOLYGON (((-0.19990 51.67017, -0.19970 51...
# 3  MULTIPOLYGON (((0.12021 51.51144, 0.12159 51.5...
# 4  MULTIPOLYGON (((-0.19657 51.52765, -0.19685 51...

# %%
# dfmg["Public Transport"] = dfmg["Underground, metro, light rail, tram"] + dfmg["Train"] + dfmg["Bus, minibus or coach"] 
# dfmg["Taxi/Motorcycle/Car/Van"] = dfmg["Taxi"] + dfmg["Motorcycle, scooter or moped"] + dfmg["Driving a car or van"] + dfmg["Passenger in a car or van"]

# %%
from sklearn.preprocessing import RobustScaler, MinMaxScaler
rs = RobustScaler(quantile_range=(10.0, 90.0))

to_cluster = dfmg[['code', 'Car', 'Public Transport', 'Bicycle/On Foot']].set_index('code').copy()
# to_cluster = dfmg[['Area code', "Work mainly at or from home", "Underground, metro, light rail, tram", 'Train', 'Bus, minibus or coach', "Taxi",
#                   "Motorcycle, scooter or moped", "Driving a car or van", "Passenger in a car or van", "Bicycle", "On foot"]].set_index('Area code').copy()
to_cluster.head()

# normnise the value
normed = to_cluster.copy()
for c in to_cluster.columns.values:
    normed[c] = rs.fit_transform(to_cluster[c].values.reshape(-1,1))
normed
# Out:
#                 Car  Public Transport  Bicycle/On Foot
# code
# E09000001 -0.664131         -0.817953        -0.567643
# E09000002 -0.061246         -0.352100        -0.399136
# E09000003  0.637856          0.412933        -0.050821
# E09000004  0.444853         -0.586273        -0.313301
# E09000005  0.173617          0.447216         0.037062
# E09000006  0.610440         -0.510067        -0.093504
# E09000007 -0.416391          0.228913         0.574962
# E09000008  0.673919         -0.116701         0.102872
# E09000009  0.485810          0.462951         0.159315
# E09000010  0.569530         -0.076342        -0.138881
# E09000011  0.026988         -0.129081        -0.169151
# E09000012 -0.376527          0.225059         0.894411
# E09000013 -0.382443          0.223857         0.354169
# E09000014 -0.188822          0.411459         0.002693
# E09000015  0.346047         -0.084165        -0.277352
# E09000016  0.477590         -0.441389        -0.274834
# E09000017  0.818220         -0.172184        -0.130567
# E09000018  0.428413         -0.045506         0.006558
# E09000019 -0.442073          0.256054         0.728363
# E09000020 -0.389380         -0.031403         0.000000
# E09000021  0.000000         -0.608947        -0.086771
# E09000022 -0.223483          0.817749         0.656405
# E09000023 -0.043143          0.000000         0.032027
# E09000024 -0.063645         -0.126519        -0.136305
# E09000025 -0.116505          0.420733        -0.124477
# E09000026  0.321981          0.059881        -0.258030
# E09000027  0.030005         -0.479526         0.025001
# E09000028 -0.264156          0.519613         0.829127
# E09000029  0.304424         -0.547728        -0.186072
# E09000030 -0.364791          0.401324         0.879012
# E09000031  0.039437          0.132868        -0.115988
# E09000032 -0.075809          0.652027         0.702308
# E09000033 -0.399833          0.243515         0.690071

# %%
import pysal as ps
import numpy as np
import pandas as pd
import seaborn as sns
import geopandas as gpd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
# calculate SSE for a range of number of cluster
list_SSE = []
min_k = 1
max_k = 10
range_k = range(min_k, max_k+1)
for i in range_k:
    km = KMeans(
        n_clusters=i, init='random',
        n_init=10, max_iter=300,
        tol=1e-04, random_state=0
    )
    km.fit(to_cluster)
    # inertia is a concept in physics. Roughly it means SSE of clustering.
    list_SSE.append(km.inertia_)

# plot
plt.plot(range_k, list_SSE, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('SSE')
plt.savefig('figpath.png', dpi=400, bbox_inches='tight')
plt.show()

# %%
# re-run the k-means process
from sklearn.cluster import KMeans
from sklearn import metrics
k_cluster = 3
random_seed = 1
kmeans_method = KMeans(n_clusters=k_cluster,random_state=random_seed)
kmeans_method.fit(normed)

gdf['Kmeans_Cluster'] = kmeans_method.labels_
fig_kmeans_4 = gdf.plot(column='Kmeans_Cluster', categorical=True, legend=True, figsize=(12,8),cmap = 'plasma')
from sklearn import metrics
print("Silhouette Score is :")
print(metrics.silhouette_score(normed, gdf['Kmeans_Cluster']))
plt.savefig('figpath.png', dpi=400, bbox_inches='tight')
# Out:
# Silhouette Score is :
# 0.37220647742260143

# %%
kmeans_label = pd.DataFrame(kmeans_method.labels_, columns = ['kmeans_label'])
kmeans_label
# to_cluster_labeled = pd.concat([to_cluster, DB_label], axis = 1).dropna()

# temp = to_cluster.join(kmeans_label)
to_cluster_labeled = to_cluster.copy()
to_cluster_labeled["kmeans_label"] = kmeans_method.labels_
to_cluster_labeled

summary_df_kmeans = to_cluster_labeled[['Car', 'Public Transport', 'Bicycle/On Foot','kmeans_label']].groupby('kmeans_label').mean().round()

summary_df_kmeans['count'] = to_cluster_labeled.kmeans_label.value_counts()
summary_df_kmeans
# Out:
#                   Car  Public Transport  Bicycle/On Foot  count
# kmeans_label
# 0             14344.0           54608.0          24007.0      9
# 1             23711.0           32958.0           9896.0     12
# 2             49584.0           31079.0           9965.0     12

# %%
gdf['Car'] = df['Car']
gdf.plot(column = 'Car',edgecolor='white',cmap='Blues',legend=True)
plt.title('Car')
plt.savefig('Car.png', dpi=800, bbox_inches='tight')

# %%
gdf['Public Transport'] = df['Public Transport']
gdf.plot(column = 'Public Transport',edgecolor='white',cmap='Blues',legend=True)
plt.title('Public Transport')
plt.savefig('Public Transport.png', dpi=800, bbox_inches='tight')

# %%
gdf['Bicycle/On Foot'] = df['Bicycle/On Foot']
gdf.plot(column = 'Bicycle/On Foot',edgecolor='white',cmap='Blues',legend=True)
plt.title('Bicycle/On Foot')
plt.savefig('Bicycle.png', dpi=800, bbox_inches='tight')
